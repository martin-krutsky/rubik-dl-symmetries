# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import torch
import seaborn as sns

import optuna_pytorch_classes.optuna_symeqnet_runner as osr

# %%
osr.run()
# Out:
# 16it [00:00, 156.69it/s]
# Size of trainset: 955, Size of testset: 239
# 955it [00:02, 336.59it/s]
# 239it [00:00, 345.25it/s]
# [I 2023-11-15 11:43:47,519] A new study created in memory with name: no-name-da839df5-9b9e-449d-a6ac-2c6afccf93b0
#   0%|                                                                                                                                                                                     | 0/1 [00:00<?, ?it/s]
# Nr of resnet blocks: 3
# batch normalization: False
# GNN layer class: GATv2Conv
# Nr of graph output channels: GATv2Conv
# 1
# Nr of hidden layer neurons: 500
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.38s/it]
# 0it [00:00, ?it/s]
# Average Training MAE before training: 2.919880965197132
# Average Test MAE before training: 2.92305916937152
# 1it [00:15, 15.27s/it]
# ...
